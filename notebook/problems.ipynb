# %% [markdown]
# # Optimization of Algorithms problems

# %% [markdown]
# ## Exercise 1: Optimization of a library management system
#
# You are provided with a code that simulates a library management system. The system has the ability to add books to the library, lend books to readers, and receive books back. In addition, it can also list all the books available in the library.
#
# The problem is that the system is very slow and needs to be optimized. Your task is to analyze the code, identify areas of improvement and rewrite parts of the code to make it more efficient. Specifically, you are asked to perform the following improvements (update the below code and implement the following points):
#
# 1. Identify and improve the data structures used to store books in the library and borrowed books. *Hint: Use an `set` instead of a `list` to store books in `Library.books` and `Library.borrowed_books` to make it more efficient to check if a book is present.**
#
# 2. Avoid errors that could occur when attempting to borrow or return a book that is not present. *Hint: Use the `set.discard()` method instead of `list.remove()` in `Library.borrow_book()` and `Library.return_book()` to avoid errors if the book is not present.*
#
# 3. Improve the efficiency of selecting a random book to lend or return. *Hint: Instead of selecting a random book from `Library.books` or `Library.borrowed_books` by indexing (which involves a conversion to list which is expensive), you can convert these sets to lists only once before the cycle.*
#
# 4. Improve the efficiency of the function that lists all the books available in the library. *Hint: Instead of printing each book one by one in `Library.list_books()`, you can construct a complete string with all book titles and then print that string once.*
#
# 5. Avoid repeated calls to `len()` in the body of loops.
#
# 6. Use list comprehension to improve efficiency of book creation.. *Hint: Use list comprehension for book creation, which can be faster than using a for loop and repeatedly calling `Library.add_book()`.*
#
# 7. Optimize checking the availability of borrowed books before attempting to return them. *Hint: Avoid checking `if library.borrowed_books:` before attempting to return a book. If you use sets and the `discard()` method, there is no need for this check.*

# %% [markdown]
# #### Read and update the following given code:

# %%
import random
import time

class Book:
    def __init__(self, id, title, author, pages):
        self.id = id
        self.title = title
        self.author = author
        self.pages = pages

class Library:
    def __init__(self, name):
        self.name = name
        self.books = {}
        self.borrowed_books = {}
   
    def add_book(self, book):
        self.books[book.id] = book

    def borrow_book(self, book_id):
         book = self.books.pop(book_id, None)
         if book:
             self.borrowed_books[book.id] = book

    def return_book(self, book_id):
        book = self.borrowed_books.pop(book_id, None)
        if book:
            self.books[book.id] = book

    def list_books(self):
        return "\n".join(book.title for book in self.books.values())


# Create a library
library = Library("Codeville")

# Add some books
library.books = {i: Book(i, f'Book {i}', f'Author {i}', i*10) for i in range(1, 101)}

# Borrow some books
book_to_borrow = [library.borrow_book(random.choice(list(library.books))) for _ in range(50)]

# Return some books
book_to_return = [library.return_book(random.choice(list(library.borrowed_books))) for _ in range(25) if library.borrowed_books]

# List all the books
start_time = time.time()
print(library.list_books())
end_time = time.time()

print(f'Listing took {end_time - start_time} seconds')
# Out:
# Book 2
# Book 7
# Book 11
# Book 14
# Book 15
# Book 17
# Book 18
# Book 19
# Book 20
# Book 22
# Book 25
# Book 26
# Book 28
# Book 31
# Book 32
# Book 38
# Book 39
# Book 41
# Book 43
# Book 44
# Book 45
# Book 46
# Book 49
# Book 50
# Book 51
# Book 53
# Book 54
# Book 55
# Book 64
# Book 65
# Book 66
# Book 68
# Book 69
# Book 71
# Book 72
# Book 73
# Book 76
# Book 77
# Book 79
# Book 80
# Book 81
# Book 82
# Book 84
# Book 85
# Book 86
# Book 90
# Book 91
# Book 92
# Book 95
# Book 97
# Book 23
# Book 98
# Book 100
# Book 12
# Book 93
# Book 47
# Book 16
# Book 37
# Book 48
# Book 4
# Book 74
# Book 40
# Book 56
# Book 87
# Book 89
# Book 24
# Book 9
# Book 27
# Book 42
# Book 10
# Book 59
# Book 61
# Book 5
# Book 83
# Book 58
# Listing took 0.00010442733764648438 seconds

# %% [markdown]
# ## Exercise 2: Task Management System Optimization
#
# You are provided with code that simulates a task management system. The system has the ability to add tasks, mark tasks as completed and list all tasks along with their status.
#
# As in the first exercise, the system is quite slow and needs to be optimized. Your task is to analyze the code, identify areas that could be improved, and rewrite parts of the code to make it more efficient. Specifically, you are asked to perform the following tasks:
#
# 1. Identify and improve the data structures used to store the tasks. *Hint: Use an `set` or `dict` instead of a `list` to store tasks in `TaskManager`, to make checking for the existence of a task more efficient.*
#
# 2. Avoid checking whether a task is in the task list each time a task is completed. *Hint: Avoid checking for the existence of a task in `TaskManager.complete_task()`. If you are sure that the task comes from `TaskManager.tasks`, it is not necessary to check if it is in the list.*
#
# 3. Restructure the way task status is tracked. *Hint: Instead of marking a task as completed by modifying its `is_done` attribute, you may consider having two sets or lists in `TaskManager`: one for pending tasks and one for completed tasks.*
#
# 4. Use list comprehension to improve the efficiency of task creation. *Hint: Use a list comprehension for task creation, which may be faster than using a for loop and repeatedly calling `TaskManager.add_task()`.*
#
# 5. Improve the efficiency of the function that lists all tasks. *Hint: Instead of printing each task one by one in `TaskManager.list_tasks()`, you can build a complete string with all tasks and then print that string once.*
#
# 6. Introduce an `id` attribute to uniquely identify each task. *Hint: Consider using an `id` attribute on the `Task` class to uniquely identify each task. This can make it easier to find and manage tasks.*
#
# 7. Avoid repeated calls to the same function or method in a loop. *Hint: Avoid repeatedly calling the same function or method in a loop, such as `TaskManager.add_task()` or `TaskManager.complete_task()`.*
#
# 8. Avoid repetition of code when calculating the status of a task. *Hint: Avoid code repetition. In `TaskManager.list_tasks()`, the task status is calculated the same way for each task. You may consider adding a method to the `Task` class that returns the status as a string.*
#
# 9. Improve code readability by using descriptive variable names. *Hint: Improve code readability by using descriptive variable names.*
#
# 10. Changes the way tasks are iterated over. *Hint: Instead of looping over a range of numbers and then indexing the list of tasks, you can iterate directly over the tasks.*

# %% [markdown]
# #### Read and update the following given code:

# %%
class Task:
    def __init__(self, id, description):
        self.id = id
        self.description = description
        self.is_done = False

    def status(self):
        return 'is done' if self.is_done else 'not done'

class TaskManager:
    def __init__(self):
        self.tasks = {}
        self.task_done = {}

    def add_task(self, task):
        self.tasks[task.id] = task

    def complete_task(self, task_id):
        if task_id in self.tasks:
            task = self.tasks.pop(task_id)
            task.is_done = True
            self.task_done[task.id] = task

    def list_tasks(self):
        task_status = [f'Task: {task.description}, Status: {task.status()}' for task in self.tasks.values()]
        task_completed = [f'Task: {task.description}, Staus: {task.status()}' for task in self.task_done.values()]
        return "\n".join(task_status + task_completed)

# Create a TaskManager
manager = TaskManager()

# Add some tasks
manager.tasks = {i: Task(i, f'Task: {i}') for i in range (1, 1001)}

# Complete some tasks
completed_task = [manager.complete_task(i) for i in range(1, 501)]


# List all the tasks
print(manager.list_tasks())
# Out:
# Task: Task: 501, Status: not done
# Task: Task: 502, Status: not done
# Task: Task: 503, Status: not done
# Task: Task: 504, Status: not done
# Task: Task: 505, Status: not done
# Task: Task: 506, Status: not done
# Task: Task: 507, Status: not done
# Task: Task: 508, Status: not done
# Task: Task: 509, Status: not done
# Task: Task: 510, Status: not done
# Task: Task: 511, Status: not done
# Task: Task: 512, Status: not done
# Task: Task: 513, Status: not done
# Task: Task: 514, Status: not done
# Task: Task: 515, Status: not done
# Task: Task: 516, Status: not done
# Task: Task: 517, Status: not done
# Task: Task: 518, Status: not done
# Task: Task: 519, Status: not done
# Task: Task: 520, Status: not done
# Task: Task: 521, Status: not done
# Task: Task: 522, Status: not done
# Task: Task: 523, Status: not done
# Task: Task: 524, Status: not done
# Task: Task: 525, Status: not done
# Task: Task: 526, Status: not done
# Task: Task: 527, Status: not done
# Task: Task: 528, Status: not done
# Task: Task: 529, Status: not done
# Task: Task: 530, Status: not done
# Task: Task: 531, Status: not done
# Task: Task: 532, Status: not done
# Task: Task: 533, Status: not done
# Task: Task: 534, Status: not done
# Task: Task: 535, Status: not done
# Task: Task: 536, Status: not done
# Task: Task: 537, Status: not done
# Task: Task: 538, Status: not done
# Task: Task: 539, Status: not done
# Task: Task: 540, Status: not done
# Task: Task: 541, Status: not done
# Task: Task: 542, Status: not done
# Task: Task: 543, Status: not done
# Task: Task: 544, Status: not done
# Task: Task: 545, Status: not done
# Task: Task: 546, Status: not done
# Task: Task: 547, Status: not done
# Task: Task: 548, Status: not done
# Task: Task: 549, Status: not done
# Task: Task: 550, Status: not done
# Task: Task: 551, Status: not done
# Task: Task: 552, Status: not done
# Task: Task: 553, Status: not done
# Task: Task: 554, Status: not done
# Task: Task: 555, Status: not done
# Task: Task: 556, Status: not done
# Task: Task: 557, Status: not done
# Task: Task: 558, Status: not done
# Task: Task: 559, Status: not done
# Task: Task: 560, Status: not done
# Task: Task: 561, Status: not done
# Task: Task: 562, Status: not done
# Task: Task: 563, Status: not done
# Task: Task: 564, Status: not done
# Task: Task: 565, Status: not done
# Task: Task: 566, Status: not done
# Task: Task: 567, Status: not done
# Task: Task: 568, Status: not done
# Task: Task: 569, Status: not done
# Task: Task: 570, Status: not done
# Task: Task: 571, Status: not done
# Task: Task: 572, Status: not done
# Task: Task: 573, Status: not done
# Task: Task: 574, Status: not done
# Task: Task: 575, Status: not done
# Task: Task: 576, Status: not done
# Task: Task: 577, Status: not done
# Task: Task: 578, Status: not done
# Task: Task: 579, Status: not done
# Task: Task: 580, Status: not done
# Task: Task: 581, Status: not done
# Task: Task: 582, Status: not done
# Task: Task: 583, Status: not done
# Task: Task: 584, Status: not done
# Task: Task: 585, Status: not done
# Task: Task: 586, Status: not done
# Task: Task: 587, Status: not done
# Task: Task: 967, Status: not done
# Task: Task: 968, Status: not done
# Task: Task: 969, Status: not done
# Task: Task: 970, Status: not done
# Task: Task: 971, Status: not done
# Task: Task: 972, Status: not done
# Task: Task: 973, Status: not done
# Task: Task: 974, Status: not done
# Task: Task: 975, Status: not done
# Task: Task: 976, Status: not done
# Task: Task: 977, Status: not done
# Task: Task: 978, Status: not done
# Task: Task: 979, Status: not done
# Task: Task: 980, Status: not done
# Task: Task: 981, Status: not done
# Task: Task: 982, Status: not done
# Task: Task: 983, Status: not done
# Task: Task: 984, Status: not done
# Task: Task: 985, Status: not done
# Task: Task: 986, Status: not done
# Task: Task: 987, Status: not done
# Task: Task: 988, Status: not done
# Task: Task: 989, Status: not done
# Task: Task: 990, Status: not done
# Task: Task: 991, Status: not done
# Task: Task: 992, Status: not done
# Task: Task: 993, Status: not done
# Task: Task: 994, Status: not done
# Task: Task: 995, Status: not done
# Task: Task: 996, Status: not done
# Task: Task: 997, Status: not done
# Task: Task: 998, Status: not done
# Task: Task: 999, Status: not done
# Task: Task: 1000, Status: not done
# Task: Task: 1, Staus: is done
# Task: Task: 2, Staus: is done
# Task: Task: 3, Staus: is done
# Task: Task: 4, Staus: is done
# Task: Task: 5, Staus: is done
# Task: Task: 6, Staus: is done
# Task: Task: 7, Staus: is done
# Task: Task: 8, Staus: is done
# Task: Task: 9, Staus: is done
# Task: Task: 10, Staus: is done
# Task: Task: 11, Staus: is done
# Task: Task: 12, Staus: is done
# Task: Task: 13, Staus: is done
# Task: Task: 14, Staus: is done
# Task: Task: 15, Staus: is done
# Task: Task: 16, Staus: is done
# Task: Task: 17, Staus: is done
# Task: Task: 18, Staus: is done
# Task: Task: 19, Staus: is done
# Task: Task: 20, Staus: is done
# Task: Task: 21, Staus: is done
# Task: Task: 22, Staus: is done
# Task: Task: 23, Staus: is done
# Task: Task: 24, Staus: is done
# Task: Task: 25, Staus: is done
# Task: Task: 26, Staus: is done
# Task: Task: 27, Staus: is done
# Task: Task: 28, Staus: is done
# Task: Task: 29, Staus: is done
# Task: Task: 30, Staus: is done
# Task: Task: 31, Staus: is done
# Task: Task: 32, Staus: is done
# Task: Task: 33, Staus: is done
# Task: Task: 34, Staus: is done
# Task: Task: 35, Staus: is done
# Task: Task: 36, Staus: is done
# Task: Task: 37, Staus: is done
# Task: Task: 38, Staus: is done
# Task: Task: 39, Staus: is done
# Task: Task: 40, Staus: is done
# Task: Task: 41, Staus: is done
# Task: Task: 42, Staus: is done
# Task: Task: 43, Staus: is done
# Task: Task: 44, Staus: is done
# Task: Task: 45, Staus: is done
# Task: Task: 46, Staus: is done
# Task: Task: 47, Staus: is done
# Task: Task: 48, Staus: is done
# Task: Task: 49, Staus: is done
# Task: Task: 50, Staus: is done
# Task: Task: 51, Staus: is done
# Task: Task: 52, Staus: is done
# Task: Task: 53, Staus: is done
# Task: Task: 54, Staus: is done
# Task: Task: 55, Staus: is done
# Task: Task: 56, Staus: is done
# Task: Task: 57, Staus: is done
# Task: Task: 58, Staus: is done
# Task: Task: 59, Staus: is done
# Task: Task: 60, Staus: is done
# Task: Task: 61, Staus: is done
# Task: Task: 62, Staus: is done
# Task: Task: 63, Staus: is done
# Task: Task: 64, Staus: is done
# Task: Task: 65, Staus: is done
# Task: Task: 66, Staus: is done
# Task: Task: 67, Staus: is done
# Task: Task: 68, Staus: is done
# Task: Task: 69, Staus: is done
# Task: Task: 70, Staus: is done
# Task: Task: 71, Staus: is done
# Task: Task: 72, Staus: is done
# Task: Task: 73, Staus: is done
# Task: Task: 74, Staus: is done
# Task: Task: 75, Staus: is done
# Task: Task: 76, Staus: is done
# Task: Task: 77, Staus: is done
# Task: Task: 78, Staus: is done
# Task: Task: 79, Staus: is done
# Task: Task: 80, Staus: is done
# Task: Task: 81, Staus: is done
# Task: Task: 82, Staus: is done
# Task: Task: 83, Staus: is done
# Task: Task: 84, Staus: is done
# Task: Task: 85, Staus: is done
# Task: Task: 86, Staus: is done
# Task: Task: 87, Staus: is done
# Task: Task: 88, Staus: is done
# Task: Task: 89, Staus: is done
# Task: Task: 90, Staus: is done
# Task: Task: 91, Staus: is done
# Task: Task: 92, Staus: is done
# Task: Task: 93, Staus: is done
# Task: Task: 94, Staus: is done
# Task: Task: 95, Staus: is done
# Task: Task: 96, Staus: is done
# Task: Task: 97, Staus: is done
# Task: Task: 98, Staus: is done
# Task: Task: 99, Staus: is done
# Task: Task: 100, Staus: is done
# Task: Task: 101, Staus: is done
# Task: Task: 102, Staus: is done
# Task: Task: 103, Staus: is done
# Task: Task: 104, Staus: is done
# Task: Task: 105, Staus: is done
# Task: Task: 106, Staus: is done
# Task: Task: 107, Staus: is done
# Task: Task: 108, Staus: is done
# Task: Task: 109, Staus: is done
# Task: Task: 110, Staus: is done
# Task: Task: 111, Staus: is done
# Task: Task: 112, Staus: is done
# Task: Task: 113, Staus: is done
# Task: Task: 114, Staus: is done
# Task: Task: 115, Staus: is done
# Task: Task: 116, Staus: is done
# Task: Task: 117, Staus: is done
# Task: Task: 118, Staus: is done
# Task: Task: 119, Staus: is done
# Task: Task: 120, Staus: is done
# Task: Task: 121, Staus: is done
# Task: Task: 122, Staus: is done
# Task: Task: 123, Staus: is done
# Task: Task: 124, Staus: is done
# Task: Task: 125, Staus: is done
# Task: Task: 126, Staus: is done
# Task: Task: 127, Staus: is done
# Task: Task: 128, Staus: is done
# Task: Task: 129, Staus: is done
# Task: Task: 130, Staus: is done
# Task: Task: 131, Staus: is done
# Task: Task: 132, Staus: is done
# Task: Task: 133, Staus: is done
# Task: Task: 134, Staus: is done
# Task: Task: 135, Staus: is done
# Task: Task: 136, Staus: is done
# Task: Task: 137, Staus: is done
# Task: Task: 138, Staus: is done
# Task: Task: 139, Staus: is done
# Task: Task: 140, Staus: is done
# Task: Task: 141, Staus: is done
# Task: Task: 142, Staus: is done
# Task: Task: 143, Staus: is done
# Task: Task: 144, Staus: is done
# Task: Task: 145, Staus: is done
# Task: Task: 146, Staus: is done
# Task: Task: 147, Staus: is done
# Task: Task: 148, Staus: is done
# Task: Task: 149, Staus: is done
# Task: Task: 150, Staus: is done
# Task: Task: 151, Staus: is done
# Task: Task: 152, Staus: is done
# Task: Task: 153, Staus: is done
# Task: Task: 154, Staus: is done
# Task: Task: 155, Staus: is done
# Task: Task: 156, Staus: is done
# Task: Task: 157, Staus: is done
# Task: Task: 158, Staus: is done
# Task: Task: 159, Staus: is done
# Task: Task: 160, Staus: is done
# Task: Task: 161, Staus: is done
# Task: Task: 162, Staus: is done
# Task: Task: 163, Staus: is done
# Task: Task: 164, Staus: is done
# Task: Task: 165, Staus: is done
# Task: Task: 166, Staus: is done
# Task: Task: 167, Staus: is done
# Task: Task: 168, Staus: is done
# Task: Task: 169, Staus: is done
# Task: Task: 170, Staus: is done
# Task: Task: 171, Staus: is done
# Task: Task: 172, Staus: is done
# Task: Task: 173, Staus: is done
# Task: Task: 174, Staus: is done
# Task: Task: 175, Staus: is done
# Task: Task: 176, Staus: is done
# Task: Task: 177, Staus: is done
# Task: Task: 178, Staus: is done
# Task: Task: 179, Staus: is done
# Task: Task: 180, Staus: is done
# Task: Task: 181, Staus: is done
# Task: Task: 182, Staus: is done
# Task: Task: 183, Staus: is done
# Task: Task: 184, Staus: is done
# Task: Task: 185, Staus: is done
# Task: Task: 186, Staus: is done
# Task: Task: 187, Staus: is done
# Task: Task: 188, Staus: is done
# Task: Task: 189, Staus: is done
# Task: Task: 190, Staus: is done
# Task: Task: 191, Staus: is done
# Task: Task: 192, Staus: is done
# Task: Task: 193, Staus: is done
# Task: Task: 194, Staus: is done
# Task: Task: 195, Staus: is done
# Task: Task: 196, Staus: is done
# Task: Task: 197, Staus: is done
# Task: Task: 198, Staus: is done
# Task: Task: 199, Staus: is done
# Task: Task: 200, Staus: is done
# Task: Task: 201, Staus: is done
# Task: Task: 202, Staus: is done
# Task: Task: 203, Staus: is done
# Task: Task: 204, Staus: is done
# Task: Task: 205, Staus: is done
# Task: Task: 206, Staus: is done
# Task: Task: 207, Staus: is done
# Task: Task: 208, Staus: is done
# Task: Task: 209, Staus: is done
# Task: Task: 210, Staus: is done
# Task: Task: 211, Staus: is done
# Task: Task: 212, Staus: is done
# Task: Task: 213, Staus: is done
# Task: Task: 214, Staus: is done
# Task: Task: 215, Staus: is done
# Task: Task: 216, Staus: is done
# Task: Task: 217, Staus: is done
# Task: Task: 218, Staus: is done
# Task: Task: 219, Staus: is done
# Task: Task: 220, Staus: is done
# Task: Task: 221, Staus: is done
# Task: Task: 222, Staus: is done
# Task: Task: 223, Staus: is done
# Task: Task: 224, Staus: is done
# Task: Task: 225, Staus: is done
# Task: Task: 226, Staus: is done
# Task: Task: 227, Staus: is done
# Task: Task: 228, Staus: is done
# Task: Task: 229, Staus: is done
# Task: Task: 230, Staus: is done
# Task: Task: 231, Staus: is done
# Task: Task: 232, Staus: is done
# Task: Task: 233, Staus: is done
# Task: Task: 234, Staus: is done
# Task: Task: 235, Staus: is done
# Task: Task: 236, Staus: is done
# Task: Task: 237, Staus: is done
# Task: Task: 238, Staus: is done
# Task: Task: 239, Staus: is done
# Task: Task: 240, Staus: is done
# Task: Task: 241, Staus: is done
# Task: Task: 242, Staus: is done
# Task: Task: 243, Staus: is done
# Task: Task: 244, Staus: is done
# Task: Task: 245, Staus: is done
# Task: Task: 246, Staus: is done
# Task: Task: 247, Staus: is done
# Task: Task: 248, Staus: is done
# Task: Task: 249, Staus: is done
# Task: Task: 250, Staus: is done
# Task: Task: 251, Staus: is done
# Task: Task: 252, Staus: is done
# Task: Task: 253, Staus: is done
# Task: Task: 254, Staus: is done
# Task: Task: 255, Staus: is done
# Task: Task: 256, Staus: is done
# Task: Task: 257, Staus: is done
# Task: Task: 258, Staus: is done
# Task: Task: 259, Staus: is done
# Task: Task: 260, Staus: is done
# Task: Task: 261, Staus: is done
# Task: Task: 262, Staus: is done
# Task: Task: 263, Staus: is done
# Task: Task: 264, Staus: is done
# Task: Task: 265, Staus: is done
# Task: Task: 266, Staus: is done
# Task: Task: 267, Staus: is done
# Task: Task: 268, Staus: is done
# Task: Task: 269, Staus: is done
# Task: Task: 270, Staus: is done
# Task: Task: 271, Staus: is done
# Task: Task: 272, Staus: is done
# Task: Task: 273, Staus: is done
# Task: Task: 274, Staus: is done
# Task: Task: 275, Staus: is done
# Task: Task: 276, Staus: is done
# Task: Task: 277, Staus: is done
# Task: Task: 278, Staus: is done
# Task: Task: 279, Staus: is done
# Task: Task: 280, Staus: is done
# Task: Task: 281, Staus: is done
# Task: Task: 282, Staus: is done
# Task: Task: 283, Staus: is done
# Task: Task: 284, Staus: is done
# Task: Task: 285, Staus: is done
# Task: Task: 286, Staus: is done
# Task: Task: 287, Staus: is done
# Task: Task: 288, Staus: is done
# Task: Task: 289, Staus: is done
# Task: Task: 290, Staus: is done
# Task: Task: 291, Staus: is done
# Task: Task: 292, Staus: is done
# Task: Task: 293, Staus: is done
# Task: Task: 294, Staus: is done
# Task: Task: 295, Staus: is done
# Task: Task: 296, Staus: is done
# Task: Task: 297, Staus: is done
# Task: Task: 298, Staus: is done
# Task: Task: 299, Staus: is done
# Task: Task: 300, Staus: is done
# Task: Task: 301, Staus: is done
# Task: Task: 302, Staus: is done
# Task: Task: 303, Staus: is done
# Task: Task: 304, Staus: is done
# Task: Task: 305, Staus: is done
# Task: Task: 306, Staus: is done
# Task: Task: 307, Staus: is done
# Task: Task: 308, Staus: is done
# Task: Task: 309, Staus: is done
# Task: Task: 310, Staus: is done
# Task: Task: 311, Staus: is done
# Task: Task: 312, Staus: is done
# Task: Task: 313, Staus: is done
# Task: Task: 314, Staus: is done
# Task: Task: 315, Staus: is done
# Task: Task: 316, Staus: is done
# Task: Task: 317, Staus: is done
# Task: Task: 318, Staus: is done
# Task: Task: 319, Staus: is done
# Task: Task: 320, Staus: is done
# Task: Task: 321, Staus: is done
# Task: Task: 322, Staus: is done
# Task: Task: 323, Staus: is done
# Task: Task: 324, Staus: is done
# Task: Task: 325, Staus: is done
# Task: Task: 326, Staus: is done
# Task: Task: 327, Staus: is done
# Task: Task: 328, Staus: is done
# Task: Task: 329, Staus: is done
# Task: Task: 330, Staus: is done
# Task: Task: 331, Staus: is done
# Task: Task: 332, Staus: is done
# Task: Task: 333, Staus: is done
# Task: Task: 334, Staus: is done
# Task: Task: 335, Staus: is done
# Task: Task: 336, Staus: is done
# Task: Task: 337, Staus: is done
# Task: Task: 338, Staus: is done
# Task: Task: 339, Staus: is done
# Task: Task: 340, Staus: is done
# Task: Task: 341, Staus: is done
# Task: Task: 342, Staus: is done
# Task: Task: 343, Staus: is done
# Task: Task: 344, Staus: is done
# Task: Task: 345, Staus: is done
# Task: Task: 346, Staus: is done
# Task: Task: 347, Staus: is done
# Task: Task: 348, Staus: is done
# Task: Task: 349, Staus: is done
# Task: Task: 350, Staus: is done
# Task: Task: 351, Staus: is done
# Task: Task: 352, Staus: is done
# Task: Task: 353, Staus: is done
# Task: Task: 354, Staus: is done
# Task: Task: 355, Staus: is done
# Task: Task: 356, Staus: is done
# Task: Task: 357, Staus: is done
# Task: Task: 358, Staus: is done
# Task: Task: 359, Staus: is done
# Task: Task: 360, Staus: is done
# Task: Task: 361, Staus: is done
# Task: Task: 362, Staus: is done
# Task: Task: 363, Staus: is done
# Task: Task: 364, Staus: is done
# Task: Task: 365, Staus: is done
# Task: Task: 366, Staus: is done
# Task: Task: 367, Staus: is done
# Task: Task: 368, Staus: is done
# Task: Task: 369, Staus: is done
# Task: Task: 370, Staus: is done
# Task: Task: 371, Staus: is done
# Task: Task: 372, Staus: is done
# Task: Task: 373, Staus: is done
# Task: Task: 374, Staus: is done
# Task: Task: 375, Staus: is done
# Task: Task: 376, Staus: is done
# Task: Task: 377, Staus: is done
# Task: Task: 378, Staus: is done
# Task: Task: 379, Staus: is done
# Task: Task: 380, Staus: is done
# Task: Task: 381, Staus: is done
# Task: Task: 382, Staus: is done
# Task: Task: 383, Staus: is done
# Task: Task: 384, Staus: is done
# Task: Task: 385, Staus: is done
# Task: Task: 386, Staus: is done
# Task: Task: 387, Staus: is done
# Task: Task: 388, Staus: is done
# Task: Task: 389, Staus: is done
# Task: Task: 390, Staus: is done
# Task: Task: 391, Staus: is done
# Task: Task: 392, Staus: is done
# Task: Task: 393, Staus: is done
# Task: Task: 394, Staus: is done
# Task: Task: 395, Staus: is done
# Task: Task: 396, Staus: is done
# Task: Task: 397, Staus: is done
# Task: Task: 398, Staus: is done
# Task: Task: 399, Staus: is done
# Task: Task: 400, Staus: is done
# Task: Task: 401, Staus: is done
# Task: Task: 402, Staus: is done
# Task: Task: 403, Staus: is done
# Task: Task: 404, Staus: is done
# Task: Task: 405, Staus: is done
# Task: Task: 406, Staus: is done
# Task: Task: 407, Staus: is done
# Task: Task: 408, Staus: is done
# Task: Task: 409, Staus: is done
# Task: Task: 410, Staus: is done
# Task: Task: 411, Staus: is done
# Task: Task: 412, Staus: is done
# Task: Task: 413, Staus: is done
# Task: Task: 414, Staus: is done
# Task: Task: 415, Staus: is done
# Task: Task: 416, Staus: is done
# Task: Task: 417, Staus: is done
# Task: Task: 418, Staus: is done
# Task: Task: 419, Staus: is done
# Task: Task: 420, Staus: is done
# Task: Task: 421, Staus: is done
# Task: Task: 422, Staus: is done
# Task: Task: 423, Staus: is done
# Task: Task: 424, Staus: is done
# Task: Task: 425, Staus: is done
# Task: Task: 426, Staus: is done
# Task: Task: 427, Staus: is done
# Task: Task: 428, Staus: is done
# Task: Task: 429, Staus: is done
# Task: Task: 430, Staus: is done
# Task: Task: 431, Staus: is done
# Task: Task: 432, Staus: is done
# Task: Task: 433, Staus: is done
# Task: Task: 434, Staus: is done
# Task: Task: 435, Staus: is done
# Task: Task: 436, Staus: is done
# Task: Task: 437, Staus: is done
# Task: Task: 438, Staus: is done
# Task: Task: 439, Staus: is done
# Task: Task: 440, Staus: is done
# Task: Task: 441, Staus: is done
# Task: Task: 442, Staus: is done
# Task: Task: 443, Staus: is done
# Task: Task: 444, Staus: is done
# Task: Task: 445, Staus: is done
# Task: Task: 446, Staus: is done
# Task: Task: 447, Staus: is done
# Task: Task: 448, Staus: is done
# Task: Task: 449, Staus: is done
# Task: Task: 450, Staus: is done
# Task: Task: 451, Staus: is done
# Task: Task: 452, Staus: is done
# Task: Task: 453, Staus: is done
# Task: Task: 454, Staus: is done
# Task: Task: 455, Staus: is done
# Task: Task: 456, Staus: is done
# Task: Task: 457, Staus: is done
# Task: Task: 458, Staus: is done
# Task: Task: 459, Staus: is done
# Task: Task: 460, Staus: is done
# Task: Task: 461, Staus: is done
# Task: Task: 462, Staus: is done
# Task: Task: 463, Staus: is done
# Task: Task: 464, Staus: is done
# Task: Task: 465, Staus: is done
# Task: Task: 466, Staus: is done
# Task: Task: 467, Staus: is done
# Task: Task: 468, Staus: is done
# Task: Task: 469, Staus: is done
# Task: Task: 470, Staus: is done
# Task: Task: 471, Staus: is done
# Task: Task: 472, Staus: is done
# Task: Task: 473, Staus: is done
# Task: Task: 474, Staus: is done
# Task: Task: 475, Staus: is done
# Task: Task: 476, Staus: is done
# Task: Task: 477, Staus: is done
# Task: Task: 478, Staus: is done
# Task: Task: 479, Staus: is done
# Task: Task: 480, Staus: is done
# Task: Task: 481, Staus: is done
# Task: Task: 482, Staus: is done
# Task: Task: 483, Staus: is done
# Task: Task: 484, Staus: is done
# Task: Task: 485, Staus: is done
# Task: Task: 486, Staus: is done
# Task: Task: 487, Staus: is done
# Task: Task: 488, Staus: is done
# Task: Task: 489, Staus: is done
# Task: Task: 490, Staus: is done
# Task: Task: 491, Staus: is done
# Task: Task: 492, Staus: is done
# Task: Task: 493, Staus: is done
# Task: Task: 494, Staus: is done
# Task: Task: 495, Staus: is done
# Task: Task: 496, Staus: is done
# Task: Task: 497, Staus: is done
# Task: Task: 498, Staus: is done
# Task: Task: 499, Staus: is done
# Task: Task: 500, Staus: is done

# %% [markdown]
# Both exercises will help you improve your code performance optimization skills and give you a better understanding of how different data structures and programming techniques can affect the efficiency of your code.
